# %%
import pandas as pd
import sys
sys.path.append('../')
from utils.loggers import LoggerMicro
from utils.testers import TestStrategyComplete
from utils.basic import run_backtest_full, get_report_complete

# %%
log_path = run_backtest_full(analyzers=[LoggerMicro],strategy=TestStrategyComplete,custom_log_prefix="test-run")
get_report_complete(log_path, html=True, console=False)
# Out:
# Starting Portfolio Value: 100000.00
# /home/fcelaya/quant/venv/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /home/fcelaya/quant/venv/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# No analysis
# Final Portfolio Value: 100095.22
# ...
