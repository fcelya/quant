# %%
import os,sys
import pandas as pd
sys.path.append("../")
from utils.basic import get_files

# %%
path = "../data/stocks/nyse"
files = get_files(path)
tickers = [f.split(".")[0] for f in files]

# %%
first = True
for file in files:
    t = pd.read_csv(os.path.join(path,file),index_col=0)
    if first:
        df = pd.DataFrame(t["close"])
        df = df.rename(columns={"close":file.split(".")[0]})
        first=False
    else:
        df = df.join(t["close"],on="date") 
        df = df.rename(columns={"close":file.split(".")[0]})
df.head()
# Out:
#                    AON        ICE        XOM        LYV        HES        IPG  \
# date
# 2017-07-31  138.169998  66.709999  80.040001  37.270000  44.540001  21.610001
# 2017-08-01  139.589996  67.279999  80.169998  37.540001  43.160000  21.740000
# 2017-08-02  139.229996  67.019997  80.599998  37.160000  44.000000  21.700001
# 2017-08-03  138.970001  65.150002  80.489998  37.320000  43.209999  21.830000
# 2017-08-04  138.949997  64.820000  80.209999  37.360001  44.349998  21.309999
#
#                   SEE        WAB        COF        SYF  ...          GD  \
# date                                                    ...
# 2017-07-31  43.509998  75.360001  86.180000  30.320000  ...  196.330002
# 2017-08-01  43.540001  73.839996  86.010002  29.879999  ...  196.529999
# 2017-08-02  43.560001  73.629997  85.709999  30.059999  ...  198.039993
# 2017-08-03  43.259998  73.430000  84.589996  29.910000  ...  199.330002
# ...

# %%
import statsmodels.api as sm

# %%
sm.correlation_tools.corr_nearest(df,1e-5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1422/1668374897.py in <module>
# ----> 1 sm.correlation_tools.corr_nearest(df,1e-5)
#
# AttributeError: module 'statsmodels.api' has no attribute 'correlation_tools'
